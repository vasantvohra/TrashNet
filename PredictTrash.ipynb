# %%
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
CATEGORIES=['cardboard','glass','metal','paper','plastic','trash']
model = tf.keras.models.load_model("Trashnet98.model")
# Out:
# WARNING:tensorflow:From c:\users\vvohra\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def prepare(filepath):
    IMG_SIZE = 150  # 50 in txt-based
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
file='cardboard64.jpg'
img=cv2.imread(file)
plt.imshow(img)
plt.show()
prediction = model.predict([prepare(file)])
print(prediction)
#print(prediction.shape)
print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# [[1. 0. 0. 0. 0. 0.]]
# cardboard

# %%
file='trash112.jpg'
img=cv2.imread(file)
plt.imshow(img)
plt.show()
prediction = model.predict([prepare(file)])
print(prediction)
print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# [[0. 0. 0. 0. 0. 1.]]
# trash

# %%
file='plastic14.jpg'
img=cv2.imread(file)
plt.imshow(img)
plt.show()
prediction = model.predict([prepare(file)])
print(prediction)
print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# [[0. 0. 0. 1. 0. 0.]]
# paper

# %%
file='paper29.jpg'
img=cv2.imread(file)
plt.imshow(img)
plt.show()
prediction = model.predict([prepare(file)])
print(prediction)
print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# [[0. 0. 0. 1. 0. 0.]]
# paper

# %%
file='glass124.jpg'
img=cv2.imread(file)
plt.imshow(img)
plt.show()
prediction = model.predict([prepare(file)])
print(prediction)
print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# [[0. 0. 0. 1. 0. 0.]]
# paper

# %%
file='metal100.jpg'
img=cv2.imread(file)
plt.imshow(img)
plt.show()
prediction = model.predict([prepare(file)])
print(prediction)
print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# [[0. 0. 1. 0. 0. 0.]]
# metal

# %%
file='plastic199.jpg'
img=cv2.imread(file)
plt.imshow(img)
plt.show()
prediction = model.predict([prepare(file)])
print(prediction)
print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# [[0. 0. 0. 0. 1. 0.]]
# plastic
